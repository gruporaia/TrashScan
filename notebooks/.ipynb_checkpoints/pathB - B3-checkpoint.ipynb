# %% [markdown]
# # TrashScan — Path B3 (5 classes)
#
# Este notebook documenta e executa o experimento **Path B3**, a variante do Path B que combina um detector YOLO previamente treinado no Path A com um classificador **ViT-B/16 pré-treinado em ImageNet21k e ajustado em ImageNet-1k**. O objetivo é avaliar se um classificador visual forte, treinado sobre recortes de objetos detectados, melhora a classificação final das 5 classes grosseiras do TrashScan: `plastic`, `paper`, `metal`, `glass` e `other`.
#
# ## Metodologia do Path B3
#
# O Path B é um pipeline em duas etapas. Primeiro, um detector YOLO localiza os objetos nas imagens completas. Depois, cada região detectada é recortada, redimensionada para 224x224 e enviada para um classificador de imagem. No B3, esse classificador é o `vit_b16_imagenet`, implementado no script de treino como `vit_base_patch16_224.augreg_in21k_ft_in1k` via `timm`.
#
# Neste notebook, o detector não é treinado novamente. Em vez disso, as runs existentes do Path A são varridas, o melhor `weights/best.pt` é selecionado com base em métricas de detecção, e esse peso é usado de forma congelada para gerar os crops do Path B. O classificador ViT-B/16 é então fine-tuned sobre esses crops, usando validação para escolher o melhor checkpoint.
#
# A avaliação considera dois níveis de resultado: métricas do classificador isolado sobre crops e uma avaliação combinada detector + classificador, que se aproxima mais do uso final do sistema em imagens completas.
#
# ## Estrutura esperada no RunPod
#
# Este notebook assume que a estrutura **já está baixada/criada no volume** do RunPod:
#
# - `/workspace/.venv`
# - `/workspace/TrashScan`
# - `/workspace/TACO`
# - `/workspace/external_datasets`
# - `/workspace/processed_5cls`
# - `/workspace/runs`
#
# O foco aqui é rodar o fluxo do **Path B** usando os scripts `.py` do projeto, sem refazer downloads, merge ou preprocessamento por padrão. As células abaixo seguem a ordem experimental: preparar ambiente, validar entradas, escolher o detector do Path A, treinar o B3, resumir métricas e executar a avaliação final combinada.

# %% [markdown]
# ## 1) Imports, paths e utilitários
#
# Os imports reúnem as bibliotecas usadas no notebook, enquanto os caminhos centralizam os diretórios importantes do RunPod. A função auxiliar `run_cmd` padroniza a execução dos scripts do projeto e imprime o comando antes de rodá-lo, o que facilita a reprodução do experimento.
#
# A organização dos caminhos importa porque o Path B3 depende de artefatos produzidos antes deste notebook: o dataset processado em `/workspace/processed_5cls` e os pesos do detector treinado no Path A em `/workspace/runs`. A célula também cria as pastas de saída do Path B e imprime os caminhos, funcionando como uma primeira checagem visual do ambiente.

# %%
from pathlib import Path
import sys
import subprocess

VENV_DIR = Path("/workspace/.venv")
REQS_PATH = Path("/workspace/TrashScan/env/environment.txt")

python_bin = VENV_DIR / "bin" / "python"
pip_bin = VENV_DIR / "bin" / "pip"

if not VENV_DIR.exists():
    print("Creating venv at", VENV_DIR)
    subprocess.run([sys.executable, "-m", "venv", str(VENV_DIR)], check=True)
else:
    print("Venv already exists at", VENV_DIR)

if not python_bin.exists():
    raise FileNotFoundError(f"python not found at {python_bin}")

if not pip_bin.exists():
    raise FileNotFoundError(f"pip not found at {pip_bin}")

subprocess.run([str(pip_bin), "install", "--upgrade", "pip"], check=True)

if REQS_PATH.exists():
    subprocess.run([str(pip_bin), "install", "-r", str(REQS_PATH)], check=True)
else:
    raise FileNotFoundError(f"requirements file not found: {REQS_PATH}")

subprocess.run([str(pip_bin), "install", "ipykernel"], check=True)
subprocess.run(
    [
        str(python_bin),
        "-m",
        "ipykernel",
        "install",
        "--user",
        "--name",
        "trashscan-venv",
        "--display-name",
        "TrashScan (.venv)",
    ],
    check=True,
)

print("Kernel registered: TrashScan (.venv)")
print("Switch the notebook kernel to use:", python_bin)
# Out:
# Venv already exists at /workspace/.venv
# Requirement already satisfied: pip in /workspace/.venv/lib/python3.11/site-packages (26.1.1)
# Requirement already satisfied: torch==2.3.1 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 2)) (2.3.1)
# Requirement already satisfied: torchvision==0.18.1 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 3)) (0.18.1)
# Requirement already satisfied: torchaudio==2.3.1 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 4)) (2.3.1)
# Requirement already satisfied: ultralytics==8.3.2 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 7)) (8.3.2)
# Requirement already satisfied: timm==1.0.3 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 10)) (1.0.3)
# Requirement already satisfied: albumentations==1.4.10 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 13)) (1.4.10)
# Requirement already satisfied: pycocotools==2.0.7 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 14)) (2.0.7)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 15)) (4.10.0.84)
# Requirement already satisfied: pillow==10.4.0 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 16)) (10.4.0)
# Requirement already satisfied: numpy==1.26.4 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 19)) (1.26.4)
# Requirement already satisfied: scipy==1.13.1 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 20)) (1.13.1)
# Requirement already satisfied: scikit-learn==1.5.1 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 21)) (1.5.1)
# Requirement already satisfied: pandas==2.2.2 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 22)) (2.2.2)
# Requirement already satisfied: matplotlib==3.9.1 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 23)) (3.9.1)
# Requirement already satisfied: mlflow==2.14.1 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 26)) (2.14.1)
# Requirement already satisfied: tqdm==4.66.4 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 29)) (4.66.4)
# Requirement already satisfied: pyyaml==6.0.1 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 30)) (6.0.1)
# Requirement already satisfied: einops==0.8.0 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 31)) (0.8.0)
# Requirement already satisfied: ensemble-boxes==1.0.9 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 32)) (1.0.9)
# Requirement already satisfied: gdown==5.2.0 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 33)) (5.2.0)
# Requirement already satisfied: roboflow==1.1.48 in /workspace/.venv/lib/python3.11/site-packages (from -r /workspace/TrashScan/env/environment.txt (line 34)) (1.1.48)
# Requirement already satisfied: filelock in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (4.15.0)
# Requirement already satisfied: sympy in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (2026.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /workspace/.venv/lib/python3.11/site-packages (from torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (2.3.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /workspace/.venv/lib/python3.11/site-packages (from ultralytics==8.3.2->-r /workspace/TrashScan/env/environment.txt (line 7)) (4.11.0.86)
# Requirement already satisfied: requests>=2.23.0 in /workspace/.venv/lib/python3.11/site-packages (from ultralytics==8.3.2->-r /workspace/TrashScan/env/environment.txt (line 7)) (2.33.1)
# Requirement already satisfied: psutil in /workspace/.venv/lib/python3.11/site-packages (from ultralytics==8.3.2->-r /workspace/TrashScan/env/environment.txt (line 7)) (7.2.2)
# Requirement already satisfied: py-cpuinfo in /workspace/.venv/lib/python3.11/site-packages (from ultralytics==8.3.2->-r /workspace/TrashScan/env/environment.txt (line 7)) (9.0.0)
# Requirement already satisfied: seaborn>=0.11.0 in /workspace/.venv/lib/python3.11/site-packages (from ultralytics==8.3.2->-r /workspace/TrashScan/env/environment.txt (line 7)) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /workspace/.venv/lib/python3.11/site-packages (from ultralytics==8.3.2->-r /workspace/TrashScan/env/environment.txt (line 7)) (2.0.18)
# Requirement already satisfied: huggingface_hub in /workspace/.venv/lib/python3.11/site-packages (from timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (1.11.0)
# Requirement already satisfied: safetensors in /workspace/.venv/lib/python3.11/site-packages (from timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (0.7.0)
# Requirement already satisfied: scikit-image>=0.21.0 in /workspace/.venv/lib/python3.11/site-packages (from albumentations==1.4.10->-r /workspace/TrashScan/env/environment.txt (line 13)) (0.26.0)
# Requirement already satisfied: pydantic>=2.7.0 in /workspace/.venv/lib/python3.11/site-packages (from albumentations==1.4.10->-r /workspace/TrashScan/env/environment.txt (line 13)) (2.13.3)
# Requirement already satisfied: albucore>=0.0.11 in /workspace/.venv/lib/python3.11/site-packages (from albumentations==1.4.10->-r /workspace/TrashScan/env/environment.txt (line 13)) (0.0.13)
# Requirement already satisfied: joblib>=1.2.0 in /workspace/.venv/lib/python3.11/site-packages (from scikit-learn==1.5.1->-r /workspace/TrashScan/env/environment.txt (line 21)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /workspace/.venv/lib/python3.11/site-packages (from scikit-learn==1.5.1->-r /workspace/TrashScan/env/environment.txt (line 21)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspace/.venv/lib/python3.11/site-packages (from pandas==2.2.2->-r /workspace/TrashScan/env/environment.txt (line 22)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /workspace/.venv/lib/python3.11/site-packages (from pandas==2.2.2->-r /workspace/TrashScan/env/environment.txt (line 22)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspace/.venv/lib/python3.11/site-packages (from pandas==2.2.2->-r /workspace/TrashScan/env/environment.txt (line 22)) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib==3.9.1->-r /workspace/TrashScan/env/environment.txt (line 23)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib==3.9.1->-r /workspace/TrashScan/env/environment.txt (line 23)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib==3.9.1->-r /workspace/TrashScan/env/environment.txt (line 23)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib==3.9.1->-r /workspace/TrashScan/env/environment.txt (line 23)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib==3.9.1->-r /workspace/TrashScan/env/environment.txt (line 23)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib==3.9.1->-r /workspace/TrashScan/env/environment.txt (line 23)) (3.3.2)
# Requirement already satisfied: Flask<4 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.1.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (1.18.4)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (8.3.3)
# Requirement already satisfied: cloudpickle<4 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.1.2)
# Requirement already satisfied: docker<8,>=4.0.0 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (7.1.0)
# Requirement already satisfied: entrypoints<1 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.1.47)
# Requirement already satisfied: graphene<4 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.4.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (7.2.1)
# Requirement already satisfied: markdown<4,>=3.3 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.10.2)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (1.41.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (1.41.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (4.25.9)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (15.0.2)
# Requirement already satisfied: querystring-parser<2 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (2.0.49)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (0.5.5)
# Requirement already satisfied: gunicorn<23 in /workspace/.venv/lib/python3.11/site-packages (from mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (22.0.0)
# Requirement already satisfied: numba in /workspace/.venv/lib/python3.11/site-packages (from ensemble-boxes==1.0.9->-r /workspace/TrashScan/env/environment.txt (line 32)) (0.65.0)
# Requirement already satisfied: beautifulsoup4 in /workspace/.venv/lib/python3.11/site-packages (from gdown==5.2.0->-r /workspace/TrashScan/env/environment.txt (line 33)) (4.14.3)
# Requirement already satisfied: certifi in /workspace/.venv/lib/python3.11/site-packages (from roboflow==1.1.48->-r /workspace/TrashScan/env/environment.txt (line 34)) (2026.4.22)
# Requirement already satisfied: idna==3.7 in /workspace/.venv/lib/python3.11/site-packages (from roboflow==1.1.48->-r /workspace/TrashScan/env/environment.txt (line 34)) (3.7)
# Requirement already satisfied: python-dotenv in /workspace/.venv/lib/python3.11/site-packages (from roboflow==1.1.48->-r /workspace/TrashScan/env/environment.txt (line 34)) (1.2.2)
# Requirement already satisfied: six in /workspace/.venv/lib/python3.11/site-packages (from roboflow==1.1.48->-r /workspace/TrashScan/env/environment.txt (line 34)) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /workspace/.venv/lib/python3.11/site-packages (from roboflow==1.1.48->-r /workspace/TrashScan/env/environment.txt (line 34)) (2.6.3)
# Requirement already satisfied: requests-toolbelt in /workspace/.venv/lib/python3.11/site-packages (from roboflow==1.1.48->-r /workspace/TrashScan/env/environment.txt (line 34)) (1.0.0)
# Requirement already satisfied: filetype in /workspace/.venv/lib/python3.11/site-packages (from roboflow==1.1.48->-r /workspace/TrashScan/env/environment.txt (line 34)) (1.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /workspace/.venv/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (12.9.86)
# Requirement already satisfied: Mako in /workspace/.venv/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (1.3.11)
# Requirement already satisfied: blinker>=1.9.0 in /workspace/.venv/lib/python3.11/site-packages (from Flask<4->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /workspace/.venv/lib/python3.11/site-packages (from Flask<4->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /workspace/.venv/lib/python3.11/site-packages (from Flask<4->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /workspace/.venv/lib/python3.11/site-packages (from Flask<4->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.1.8)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /workspace/.venv/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /workspace/.venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (5.0.3)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /workspace/.venv/lib/python3.11/site-packages (from graphene<4->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.2.8)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /workspace/.venv/lib/python3.11/site-packages (from graphene<4->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in /workspace/.venv/lib/python3.11/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.23.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in /workspace/.venv/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (0.62b0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspace/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics==8.3.2->-r /workspace/TrashScan/env/environment.txt (line 7)) (3.4.7)
# Requirement already satisfied: greenlet>=1 in /workspace/.venv/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.14.1->-r /workspace/TrashScan/env/environment.txt (line 26)) (3.4.0)
# Requirement already satisfied: tomli>=2.0.1 in /workspace/.venv/lib/python3.11/site-packages (from albucore>=0.0.11->albumentations==1.4.10->-r /workspace/TrashScan/env/environment.txt (line 13)) (2.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspace/.venv/lib/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.10->-r /workspace/TrashScan/env/environment.txt (line 13)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /workspace/.venv/lib/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.10->-r /workspace/TrashScan/env/environment.txt (line 13)) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /workspace/.venv/lib/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.10->-r /workspace/TrashScan/env/environment.txt (line 13)) (0.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /workspace/.venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->-r /workspace/TrashScan/env/environment.txt (line 13)) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /workspace/.venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->-r /workspace/TrashScan/env/environment.txt (line 13)) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /workspace/.venv/lib/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.10->-r /workspace/TrashScan/env/environment.txt (line 13)) (0.5)
# Requirement already satisfied: soupsieve>=1.6.1 in /workspace/.venv/lib/python3.11/site-packages (from beautifulsoup4->gdown==5.2.0->-r /workspace/TrashScan/env/environment.txt (line 33)) (2.8.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /workspace/.venv/lib/python3.11/site-packages (from huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /workspace/.venv/lib/python3.11/site-packages (from huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (0.28.1)
# Requirement already satisfied: typer in /workspace/.venv/lib/python3.11/site-packages (from huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (0.24.2)
# Requirement already satisfied: anyio in /workspace/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /workspace/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /workspace/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (0.16.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /workspace/.venv/lib/python3.11/site-packages (from numba->ensemble-boxes==1.0.9->-r /workspace/TrashScan/env/environment.txt (line 32)) (0.47.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /workspace/.venv/lib/python3.11/site-packages (from requests[socks]->gdown==5.2.0->-r /workspace/TrashScan/env/environment.txt (line 33)) (1.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /workspace/.venv/lib/python3.11/site-packages (from sympy->torch==2.3.1->-r /workspace/TrashScan/env/environment.txt (line 2)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /workspace/.venv/lib/python3.11/site-packages (from typer->huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /workspace/.venv/lib/python3.11/site-packages (from typer->huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /workspace/.venv/lib/python3.11/site-packages (from typer->huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /workspace/.venv/lib/python3.11/site-packages (from rich>=12.3.0->typer->huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /workspace/.venv/lib/python3.11/site-packages (from rich>=12.3.0->typer->huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /workspace/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->timm==1.0.3->-r /workspace/TrashScan/env/environment.txt (line 10)) (0.1.2)
# Requirement already satisfied: ipykernel in /workspace/.venv/lib/python3.11/site-packages (7.2.0)
# Requirement already satisfied: comm>=0.1.1 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (9.10.1)
# Requirement already satisfied: jupyter-client>=8.8.0 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil>=5.7 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator>=4.3.2 in /workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /workspace/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.15.0)
# Requirement already satisfied: wcwidth in /workspace/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /workspace/.venv/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-client>=8.8.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.9.6)
# Requirement already satisfied: ptyprocess>=0.5 in /workspace/.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /workspace/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /workspace/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /workspace/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in /workspace/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Installed kernelspec trashscan-venv in /root/.local/share/jupyter/kernels/trashscan-venv
# Kernel registered: TrashScan (.venv)
# Switch the notebook kernel to use: /workspace/.venv/bin/python

# %%
from pathlib import Path
import os
import sys
import shlex
import subprocess
import shutil
import torch
import pandas as pd
import json

# Caminhos principais no RunPod
WORKSPACE = Path('/workspace')
REPO_ROOT = WORKSPACE / 'TrashScan'

DATA_DIR = REPO_ROOT / 'data'
TRAIN_DIR = REPO_ROOT / 'train' / 'paths'
EVAL_DIR = REPO_ROOT / 'eval'

EXTERNAL_DIR = WORKSPACE / 'external_datasets'
TACO_DIR = WORKSPACE / 'TACO'
PROCESSED_DIR = WORKSPACE / 'processed_5cls'

DATASET_YAML_PATH_A = PROCESSED_DIR / 'dataset_path_A.yaml'
DATASET_YAML_PATH_B = PROCESSED_DIR / 'dataset_path_B.yaml'

# Path A: necessário porque o Path B usa o melhor detector treinado no Path A
RUNS_PATH_A_DIR = WORKSPACE / 'runs' / 'path_A'

# Path B3: treino do classificador ViT-B/16 ImageNet21k
RUNS_PATH_B_DIR = WORKSPACE / 'runs' / 'path_B_5cls'
MLFLOW_DIR = Path('/root/mlflow')

# Resultados finais persistentes no volume
RESULTS_PATH_B_DIR = WORKSPACE / 'results_path_B'

# Scripts principais
TRAIN_PATH_B_SCRIPT = TRAIN_DIR / 'train_path_B.py'

for p in [RUNS_PATH_B_DIR, MLFLOW_DIR, RESULTS_PATH_B_DIR]:
    p.mkdir(parents=True, exist_ok=True)

print('Python             =', sys.executable)
print('REPO_ROOT          =', REPO_ROOT)
print('TACO_DIR           =', TACO_DIR)
print('EXTERNAL_DIR       =', EXTERNAL_DIR)
print('PROCESSED_DIR      =', PROCESSED_DIR)
print('DATASET_YAML_PATH_A=', DATASET_YAML_PATH_A)
print('DATASET_YAML_PATH_B=', DATASET_YAML_PATH_B)
print('RUNS_PATH_A_DIR    =', RUNS_PATH_A_DIR)
print('RUNS_PATH_B_DIR    =', RUNS_PATH_B_DIR)
print('MLFLOW_DIR         =', MLFLOW_DIR)
print('RESULTS_PATH_B_DIR =', RESULTS_PATH_B_DIR)
print('TRAIN_PATH_B_SCRIPT=', TRAIN_PATH_B_SCRIPT)


def run_cmd(cmd, cwd=WORKSPACE, env=None):
    """Roda comandos de forma previsível no notebook."""
    if isinstance(cmd, str):
        print('$', cmd)
        return subprocess.run(cmd, cwd=str(cwd), shell=True, env=env, check=True)
    print('$', ' '.join(shlex.quote(str(x)) for x in cmd))
    return subprocess.run([str(x) for x in cmd], cwd=str(cwd), env=env, check=True)
# Out:
# Python             = /workspace/.venv/bin/python
# REPO_ROOT          = /workspace/TrashScan
# TACO_DIR           = /workspace/TACO
# EXTERNAL_DIR       = /workspace/external_datasets
# PROCESSED_DIR      = /workspace/processed_5cls
# DATASET_YAML_PATH_A= /workspace/processed_5cls/dataset_path_A.yaml
# DATASET_YAML_PATH_B= /workspace/processed_5cls/dataset_path_B.yaml
# RUNS_PATH_A_DIR    = /workspace/runs/path_A
# RUNS_PATH_B_DIR    = /workspace/runs/path_B_5cls
# MLFLOW_DIR         = /root/mlflow
# RESULTS_PATH_B_DIR = /workspace/results_path_B
# TRAIN_PATH_B_SCRIPT= /workspace/TrashScan/train/paths/train_path_B.py

# %% [markdown]
# ## 2) Verificação dos arquivos principais
#
# Antes de iniciar a seleção de pesos ou o treino, esta checagem confirma se existem o script `train_path_B.py`, o diretório processado de 5 classes e ao menos a pasta-base de runs do Path A.
#
# Se algo estiver ausente, o notebook lista explicitamente o caminho faltante. Isso evita gastar tempo depurando erros posteriores de treino que, na prática, seriam apenas consequência de arquivos não montados ou preprocessamento não executado.

# %%
required_paths = [
    TRAIN_PATH_B_SCRIPT,
    PROCESSED_DIR,
    RUNS_PATH_A_DIR,
]

missing = [str(p) for p in required_paths if not p.exists()]

if missing:
    print("Arquivos/pastas ausentes:")
    for p in missing:
        print(" -", p)
else:
    print("Tudo certo.")
# Out:
# Tudo certo.

# %% [markdown]
# ## 3) Configuração de GPU e hiperparâmetros do B3
#
# A escolha do dispositivo é feita automaticamente: GPU `0` quando CUDA está disponível, ou CPU caso contrário. Em seguida, ficam definidos os principais hiperparâmetros do fine-tuning.
#
# Para o B3, o classificador selecionado é apenas `vit_b16_imagenet`. O treino é configurado para até 100 épocas, batch size 8, learning rate `5e-5`, early stopping com paciência 10 e limiar de confiança `0.25` para o detector YOLO usado na geração dos crops.

# %%
if torch.cuda.is_available():
    DEVICE = "0"
    gpu_name = torch.cuda.get_device_properties(0).name
else:
    DEVICE = "cpu"
    gpu_name = "cpu"

print("Device:", DEVICE)
print("GPU:", gpu_name)

EPOCHS = 100
BATCH = 8
LR = 5e-5
PATIENCE = 10
DET_CONF = 0.25

CLASSIFIERS = [
    "vit_b16_imagenet",
]
# Out:
# Device: 0
# GPU: NVIDIA RTX 4000 Ada Generation

# %% [markdown]
# ## 4) Encontrar o melhor peso do Path A
#
# A escolha do detector YOLO define a primeira etapa do pipeline Path B3. Como o B3 avalia classificação a partir de objetos detectados, a qualidade do detector influencia diretamente quais crops chegam ao ViT.
#
# A célula percorre diferentes diretórios de runs do Path A, procura checkpoints `weights/best.pt` e lê métricas de `results.csv` ou, se necessário, de `metrics.json`. Os candidatos são ranqueados priorizando `mAP50-95`; se essa métrica não existir, o ranking usa `mAP50`. O melhor checkpoint encontrado é salvo em `DETECTOR_WEIGHTS` para ser usado nas próximas etapas.

# %%
PATH_A_RUN_DIRS = [
    WORKSPACE / "runs" / "path_A",
    WORKSPACE / "runs" / "path_A_5cls",
    WORKSPACE / "runs" / "path_A_refined_head",
]

def read_yolo_results(run_dir: Path):
    """
    Lê métricas de uma pasta de treino YOLO.
    Espera estrutura:
      run_dir/
        weights/best.pt
        results.csv
        args.yaml
    """
    best_pt = run_dir / "weights" / "best.pt"
    results_csv = run_dir / "results.csv"
    metrics_json = run_dir / "metrics.json"

    if not best_pt.exists():
        return None

    row = {
        "group": run_dir.parent.name,
        "model": run_dir.name,
        "run_dir": run_dir,
        "best_pt": best_pt,
        "mAP50_95": None,
        "mAP50": None,
        "precision": None,
        "recall": None,
        "source": None,
    }

    if results_csv.exists():
        df = pd.read_csv(results_csv)
        df.columns = [c.strip() for c in df.columns]

        # Melhor época por mAP50-95, se existir
        map95_col = "metrics/mAP50-95(B)"
        map50_col = "metrics/mAP50(B)"
        precision_col = "metrics/precision(B)"
        recall_col = "metrics/recall(B)"

        if map95_col in df.columns:
            best_idx = df[map95_col].idxmax()
        elif map50_col in df.columns:
            best_idx = df[map50_col].idxmax()
        else:
            best_idx = df.index[-1]

        best = df.loc[best_idx]

        row["mAP50_95"] = float(best[map95_col]) if map95_col in df.columns else None
        row["mAP50"] = float(best[map50_col]) if map50_col in df.columns else None
        row["precision"] = float(best[precision_col]) if precision_col in df.columns else None
        row["recall"] = float(best[recall_col]) if recall_col in df.columns else None
        row["source"] = "results.csv"
        return row

    # Fallback para metrics.json, se existir
    if metrics_json.exists():
        with open(metrics_json, "r") as f:
            m = json.load(f)

        row["mAP50_95"] = m.get("mAP50_95")
        row["mAP50"] = m.get("mAP50")
        row["precision"] = m.get("precision")
        row["recall"] = m.get("recall")
        row["source"] = "metrics.json"
        return row

    # Tem best.pt, mas sem métrica
    row["source"] = "weights_only"
    return row


records = []

for base_dir in PATH_A_RUN_DIRS:
    if not base_dir.exists():
        print(f"[warn] Pasta não encontrada: {base_dir}")
        continue

    for run_dir in sorted(base_dir.iterdir()):
        if not run_dir.is_dir():
            continue

        rec = read_yolo_results(run_dir)
        if rec is not None:
            records.append(rec)

df_detectors = pd.DataFrame(records)

if df_detectors.empty:
    raise FileNotFoundError(
        "Nenhum detector com weights/best.pt foi encontrado em: "
        + ", ".join(str(p) for p in PATH_A_RUN_DIRS)
    )

# Ordena pelo melhor critério disponível
df_ranked = df_detectors.copy()
df_ranked["rank_score"] = df_ranked["mAP50_95"].fillna(df_ranked["mAP50"]).fillna(-1)

df_ranked = df_ranked.sort_values(
    by=["rank_score", "mAP50", "precision", "recall"],
    ascending=False,
    na_position="last",
).reset_index(drop=True)

display_cols = [
    "group", "model", "mAP50_95", "mAP50", "precision", "recall", "source", "best_pt"
]

display(df_ranked[display_cols])

best_detector = df_ranked.iloc[0]
DETECTOR_WEIGHTS = Path(best_detector["best_pt"])

print("Melhor detector encontrado:")
print("Grupo :", best_detector["group"])
print("Modelo:", best_detector["model"])
print("mAP50-95:", best_detector["mAP50_95"])
print("mAP50:", best_detector["mAP50"])
print("Pesos:", DETECTOR_WEIGHTS)

if not DETECTOR_WEIGHTS.exists():
    raise FileNotFoundError(f"Detector não encontrado: {DETECTOR_WEIGHTS}")
# Out:
#                  group         model  mAP50_95    mAP50  precision   recall  \
# 0          path_A_5cls  yolov11m_o2o   0.49421  0.71055    0.79748  0.64537
# 1          path_A_5cls      yolov11m   0.45791  0.66802    0.76878  0.61979
# 2          path_A_5cls       yolov8m   0.45466  0.67461    0.81395  0.59336
# 3               path_A      yolov11m   0.44551  0.64990    0.70430  0.58665
# 4               path_A  yolov11m_o2o   0.44040  0.64164    0.68838  0.59821
# 5               path_A      yolov10m   0.39211  0.57796    0.63463  0.53399
# 6               path_A       yolov9s   0.38005  0.57062    0.65521  0.51124
# 7  path_A_refined_head      yolov10n   0.04614  0.11337    0.18439  0.16914
# 8               path_A       yolov8m       NaN      NaN        NaN      NaN
#
#          source                                            best_pt
# 0   results.csv  /workspace/runs/path_A_5cls/yolov11m_o2o/weigh...
# 1   results.csv  /workspace/runs/path_A_5cls/yolov11m/weights/b...
# 2   results.csv  /workspace/runs/path_A_5cls/yolov8m/weights/be...
# 3   results.csv    /workspace/runs/path_A/yolov11m/weights/best.pt
# 4   results.csv  /workspace/runs/path_A/yolov11m_o2o/weights/be...
# 5   results.csv    /workspace/runs/path_A/yolov10m/weights/best.pt
# 6   results.csv     /workspace/runs/path_A/yolov9s/weights/best.pt
# 7   results.csv  /workspace/runs/path_A_refined_head/yolov10n/w...
# 8  weights_only     /workspace/runs/path_A/yolov8m/weights/best.pt
# Melhor detector encontrado:
# Grupo : path_A_5cls
# Modelo: yolov11m_o2o
# mAP50-95: 0.49421
# mAP50: 0.71055
# Pesos: /workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt

# %% [markdown]
# ## 5) Conferir estrutura do Path B
#
# A checagem percorre os splits de treinamento, validação e teste para confirmar que o dataset processado possui a estrutura esperada. O script do Path B espera encontrar, para cada split, a pasta `path_B` com `images`, `labels` e `crops`.
#
# Mesmo quando o treino usa `--use_yolo_crops`, as imagens e labels continuam necessárias: o YOLO gera detecções nas imagens, e as labels são usadas para associar cada box detectada à classe correta durante a construção dos crops supervisionados.

# %%
for split in ["train", "val", "test"]:
    path_b_dir = PROCESSED_DIR / split / "path_B"
    print(split, path_b_dir, "->", path_b_dir.exists())

    for sub in ["images", "labels", "crops"]:
        p = path_b_dir / sub
        print("  ", sub, "->", p.exists())
# Out:
# train /workspace/processed_5cls/train/path_B -> True
#    images -> True
#    labels -> True
#    crops -> True
# val /workspace/processed_5cls/val/path_B -> True
#    images -> True
#    labels -> True
#    crops -> True
# test /workspace/processed_5cls/test/path_B -> True
#    images -> True
#    labels -> True
#    crops -> True

# %% [markdown]
# ## 6) Treino Path B3 — ViT-B/16 fine-tuning (TTA no YOLO)
#
# O fine-tuning do B3 usa crops produzidos pelo detector YOLO selecionado, com TTA ativado na etapa de detecção. Nesta etapa, apenas o classificador é treinado; o detector entra como modelo congelado para localizar objetos e gerar os recortes.
#
# O comando usa `--use_yolo_crops` e `--tta`, então os crops vêm das detecções com TTA. Os crops são salvos em cache para acelerar reexecuções, e o script registra `history.csv`, `metrics.json`, `weights/best.pt` e matriz de confusão dentro da run do classificador.

# %%
print("\nParametros:")

RUNS_PATH_B_DIR.mkdir(parents=True, exist_ok=True)

print(f"Python executable: {sys.executable}")
print(f"Script: {TRAIN_PATH_B_SCRIPT}")
print(f"Detector weights: {DETECTOR_WEIGHTS}")
print(f"Crops dir: {PROCESSED_DIR}")
print(f"Output dir: {RUNS_PATH_B_DIR}")
print(f"Classifiers: {CLASSIFIERS}")
print(f"Epochs: {EPOCHS}")
print(f"Batch: {BATCH}")
print(f"Learning rate: {LR}")
print(f"Patience: {PATIENCE}")
print(f"Device: {DEVICE}")
print("Use YOLO crops: True")
print(f"Detection confidence: {DET_CONF}")
print(f"Crop cache dir: {RUNS_PATH_B_DIR / 'crop_cache_tta'}")
# Out:
# Parametros:
# Python executable: /workspace/.venv/bin/python
# Script: /workspace/TrashScan/train/paths/train_path_B.py
# Detector weights: /workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt
# Crops dir: /workspace/processed_5cls
# Output dir: /workspace/runs/path_B_5cls
# Classifiers: ['vit_b16_imagenet']
# Epochs: 100
# Batch: 8
# Learning rate: 5e-05
# Patience: 10
# Device: 0
# Use YOLO crops: True
# Detection confidence: 0.25
# Crop cache dir: /workspace/runs/path_B_5cls/crop_cache_tta

# %%
run_cmd([
    sys.executable, str(TRAIN_PATH_B_SCRIPT),
    "--detector_weights", str(DETECTOR_WEIGHTS),
    "--crops_dir", str(PROCESSED_DIR),
    "--output", str(RUNS_PATH_B_DIR),
    "--classifiers", *CLASSIFIERS,
    "--epochs", str(EPOCHS),
    "--batch", str(BATCH),
    "--lr", str(LR),
    "--patience", str(PATIENCE),
    "--device", str(DEVICE),
    "--use_yolo_crops",
    "--det_conf", str(DET_CONF),
    "--tta",
    "--crop_cache_dir", str(RUNS_PATH_B_DIR / "crop_cache_tta"),
])
# Out:
# $ /workspace/.venv/bin/python /workspace/TrashScan/train/paths/train_path_B.py --detector_weights /workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt --crops_dir /workspace/processed_5cls --output /workspace/runs/path_B_5cls --classifiers vit_b16_imagenet --epochs 100 --batch 8 --lr 5e-05 --patience 10 --device 0 --use_yolo_crops --det_conf 0.25 --tta --crop_cache_dir /workspace/runs/path_B_5cls/crop_cache_tta
# Device : cuda:0
# GPU    : NVIDIA RTX 4000 Ada Generation  VRAM: 21.1GB
# Class weights: {'plastic': 0.511, 'paper': 1.098, 'metal': 1.125, 'glass': 1.777, 'other': 0.489}
#
#   Mode: YOLO on-the-fly crop extraction
#   YOLO TTA: True
#
#   [train] Building YOLOCropDataset via YOLO detection…
#   [train] YOLO crops: 100%|██████████| 6491/6491 [15:21<00:00,  7.04it/s]
#   [val] YOLO crops:   0%|          | 0/1392 [00:00<?, ?it/s]
#   [train] 12087 matched crops  (456 images with no GT or no detections skipped)
#
#   [val] Building YOLOCropDataset via YOLO detection…
#   [val] YOLO crops: 100%|██████████| 1392/1392 [03:18<00:00,  7.00it/s]
#   [test] YOLO crops:   0%|          | 0/1391 [00:00<?, ?it/s]
#   [val] 2405 matched crops  (99 images with no GT or no detections skipped)
#
#   [test] Building YOLOCropDataset via YOLO detection…
#   [test] YOLO crops: 100%|██████████| 1391/1391 [03:15<00:00,  7.11it/s]
#   [test] 2375 matched crops  (110 images with no GT or no detections skipped)
#
# ────────────────────────────────────────────────────────────
#   Classifier : vit_b16_imagenet
# ────────────────────────────────────────────────────────────
#   Built vit_b16_imagenet (vit_base_patch16_224.augreg_in21k_ft_in1k)  pretrained=True  85.8M params
#   Ep   1/100 | train loss=0.8817 acc=0.7214 | val loss=0.6124 acc=0.8146 f1=0.7486
#   Ep   2/100 | train loss=0.5841 acc=0.8080 | val loss=0.4934 acc=0.8474 f1=0.7926
#   Ep 4/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep   3/100 | train loss=0.4883 acc=0.8410 | val loss=0.4436 acc=0.8374 f1=0.8111
#   Ep   4/100 | train loss=0.4180 acc=0.8595 | val loss=0.3937 acc=0.8719 f1=0.8304
#   Ep 6/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep   5/100 | train loss=0.3541 acc=0.8795 | val loss=0.4528 acc=0.8532 f1=0.7976
#   Ep   6/100 | train loss=0.3317 acc=0.8881 | val loss=0.4475 acc=0.8782 f1=0.8308
#   Ep   7/100 | train loss=0.3101 acc=0.8958 | val loss=0.3718 acc=0.8977 f1=0.8682
#   Ep   8/100 | train loss=0.2866 acc=0.9058 | val loss=0.3576 acc=0.9035 f1=0.8904
#   Ep 10/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep   9/100 | train loss=0.2708 acc=0.9056 | val loss=0.3679 acc=0.8998 f1=0.8835
#   Ep 11/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  10/100 | train loss=0.2379 acc=0.9173 | val loss=0.3880 acc=0.8977 f1=0.8848
#   Ep  11/100 | train loss=0.2486 acc=0.9133 | val loss=0.3469 acc=0.9085 f1=0.8969
#   Ep 13/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  12/100 | train loss=0.2163 acc=0.9214 | val loss=0.3575 acc=0.9060 f1=0.8900
#   Ep 14/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  13/100 | train loss=0.2206 acc=0.9217 | val loss=0.3605 acc=0.9069 f1=0.8950
#   Ep 15/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  14/100 | train loss=0.2052 acc=0.9270 | val loss=0.4272 acc=0.8877 f1=0.8723
#   Ep 16/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  15/100 | train loss=0.2095 acc=0.9277 | val loss=0.4069 acc=0.9085 f1=0.8932
#   Ep 17/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  16/100 | train loss=0.1995 acc=0.9271 | val loss=0.3693 acc=0.9040 f1=0.8874
#   Ep 18/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  17/100 | train loss=0.1978 acc=0.9277 | val loss=0.3699 acc=0.9064 f1=0.8910
#   Ep  18/100 | train loss=0.1905 acc=0.9324 | val loss=0.3469 acc=0.9152 f1=0.9055
#   Ep 20/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  19/100 | train loss=0.1835 acc=0.9322 | val loss=0.3708 acc=0.9081 f1=0.8927
#   Ep 21/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  20/100 | train loss=0.1669 acc=0.9363 | val loss=0.4118 acc=0.8973 f1=0.8910
#   Ep 22/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  21/100 | train loss=0.1776 acc=0.9332 | val loss=0.4144 acc=0.9015 f1=0.8862
#   Ep 23/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  22/100 | train loss=0.1830 acc=0.9331 | val loss=0.4370 acc=0.8769 f1=0.8575
#   Ep 24/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  23/100 | train loss=0.1643 acc=0.9392 | val loss=0.3657 acc=0.9110 f1=0.8982
#   Ep 25/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  24/100 | train loss=0.1748 acc=0.9358 | val loss=0.4237 acc=0.9119 f1=0.8979
#   Ep 26/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  25/100 | train loss=0.1646 acc=0.9389 | val loss=0.4143 acc=0.9010 f1=0.8884
#   Ep 27/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  26/100 | train loss=0.1554 acc=0.9393 | val loss=0.4703 acc=0.9131 f1=0.9043
#   Ep 28/100 train:   0%|          | 0/1511 [00:00<?, ?it/s]
#   Ep  27/100 | train loss=0.1524 acc=0.9422 | val loss=0.4162 acc=0.9098 f1=0.9054
#   Ep  28/100 | train loss=0.1577 acc=0.9389 | val loss=0.4189 acc=0.9069 f1=0.8976
#   Early stopping at epoch 28 (best epoch 18, val_acc=0.9152)
#   Test: 100%|██████████| 297/297 [00:09<00:00, 31.10it/s]
#   [vit_b16_imagenet]  accuracy=0.9154  f1=0.9032  latency=11.71ms
#
#   [vit_b16_imagenet]  best_epoch=18  val_acc=0.9152  test_acc=0.9154  f1=0.9032
#
# ======================================================================
# PATH B  —  CLASSIFIER BENCHMARK SUMMARY
# ======================================================================
#                   accuracy  precision  recall     f1  latency_ms  AP_plastic  AP_paper  AP_metal  AP_glass  AP_other
# classifier
# vit_b16_imagenet    0.9154     0.8826  0.9278 0.9032     11.7140      0.9659    0.9334    0.8559    0.9513    0.9677
# ======================================================================
# CompletedProcess(args=['/workspace/.venv/bin/python', '/workspace/TrashScan/train/paths/train_path_B.py', '--detector_weights', '/workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt', '--crops_dir', '/workspace/processed_5cls', '--output', '/workspace/runs/path_B_5cls', '--classifiers', 'vit_b16_imagenet', '--epochs', '100', '--batch', '8', '--lr', '5e-05', '--patience', '10', '--device', '0', '--use_yolo_crops', '--det_conf', '0.25', '--tta', '--crop_cache_dir', '/workspace/runs/path_B_5cls/crop_cache_tta'], returncode=0)

# %%
run_dir = Path("/workspace/runs/path_B_5cls/vit_b16_imagenet")

print("best.pt:", (run_dir / "weights" / "best.pt").exists())
print("history.csv:", (run_dir / "history.csv").exists())
print("metrics.json:", (run_dir / "metrics.json").exists())

if (run_dir / "metrics.json").exists():
    print(json.loads((run_dir / "metrics.json").read_text()))

if (run_dir / "history.csv").exists():
    hist = pd.read_csv(run_dir / "history.csv")
    display(hist.tail())
# Out:
# best.pt: True
# history.csv: True
# metrics.json: True
# {'classifier': 'vit_b16_imagenet', 'accuracy': 0.91537, 'precision': 0.88258, 'recall': 0.92785, 'f1': 0.90321, 'latency_ms': 11.714, 'AP_plastic': 0.9659, 'AP_paper': 0.93342, 'AP_metal': 0.85586, 'AP_glass': 0.95129, 'AP_other': 0.96765}
#     epoch  train_loss  train_acc  val_loss  val_acc   val_f1        lr
# 23     24     0.17484    0.93580   0.42372  0.91185  0.89792  0.000043
# 24     25     0.16462    0.93886   0.41430  0.90104  0.88838  0.000043
# 25     26     0.15537    0.93927   0.47029  0.91310  0.90428  0.000042
# 26     27     0.15243    0.94217   0.41621  0.90977  0.90541  0.000042
# 27     28     0.15772    0.93894   0.41887  0.90686  0.89755  0.000041

# %% [markdown]
# ## 7) Resumo do treino
#
# O resumo consolida os resultados já salvos pelo script do Path B. A opção `--summarize` percorre as runs disponíveis em `/workspace/runs/path_B_5cls` e imprime uma visão resumida das métricas do classificador treinado no B3 com TTA.
#
# Também há redefinição explícita de alguns caminhos para facilitar reexecuções isoladas a partir daqui. Atenção: `DETECTOR_WEIGHTS` passa a apontar manualmente para `/workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt`.

# %%
def run_cmd(cmd, cwd="/workspace", env=None, shell=False):
    print("$", " ".join(shlex.quote(str(x)) for x in cmd))
    if shell:
        return subprocess.run(cmd, cwd=str(cwd), shell=True, env=env, check=True)
    return subprocess.run([str(x) for x in cmd], cwd=str(cwd), env=env, check=True)
   
TRAIN_PATH_B_SCRIPT = Path("/workspace/TrashScan/train/paths/train_path_B.py")
RUNS_PATH_B_DIR = Path("/workspace/runs/path_B_5cls")
DETECTOR_WEIGHTS = Path("/workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt")
PROCESSED_DIR = Path("/workspace/processed_5cls")

# %%
run_cmd([
    sys.executable, str(TRAIN_PATH_B_SCRIPT),
    "--detector_weights", str(DETECTOR_WEIGHTS),
    "--crops_dir", str(PROCESSED_DIR),
    "--output", str(RUNS_PATH_B_DIR),
    "--summarize",
])
# Out:
# $ /workspace/.venv/bin/python /workspace/TrashScan/train/paths/train_path_B.py --detector_weights /workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt --crops_dir /workspace/processed_5cls --output /workspace/runs/path_B_5cls --summarize
#
# ======================================================================
# PATH B  —  CLASSIFIER BENCHMARK SUMMARY
# ======================================================================
#                   accuracy  precision  recall     f1  latency_ms  AP_plastic  AP_paper  AP_metal  AP_glass  AP_other
# classifier
# vit_b16_imagenet    0.9154     0.8826  0.9278 0.9032     11.7140      0.9659    0.9334    0.8559    0.9513    0.9677
# ======================================================================
# CompletedProcess(args=['/workspace/.venv/bin/python', '/workspace/TrashScan/train/paths/train_path_B.py', '--detector_weights', '/workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt', '--crops_dir', '/workspace/processed_5cls', '--output', '/workspace/runs/path_B_5cls', '--summarize'], returncode=0)

# %% [markdown]
# ## 8) Ver métricas do ViT-B/16 (TTA)
#
# A inspeção final olha para os artefatos da run `vit_b16_imagenet` dentro de `/workspace/runs/path_B_5cls`. O histórico de treino é lido para encontrar as melhores épocas por acurácia de validação e F1 macro de validação, e essas informações são combinadas com as métricas de teste salvas em `metrics.json`.
#
# As principais leituras desta seção são: quantas épocas foram treinadas, se `weights/best.pt` foi salvo, qual foi a melhor validação, qual foi o desempenho no teste e se a matriz de confusão foi gerada. As métricas macro são importantes porque o dataset de resíduos tende a ser desbalanceado; elas reduzem o risco de interpretar apenas a performance nas classes mais frequentes.

# %%
RUN_DIR = Path("/workspace/runs/path_B_5cls/vit_b16_imagenet")

history_path = RUN_DIR / "history.csv"
metrics_path = RUN_DIR / "metrics.json"
best_weights_path = RUN_DIR / "weights" / "best.pt"
cm_path = RUN_DIR / "confusion_matrix_vit_b16_imagenet.png"

print("Run dir:", RUN_DIR)
print("best.pt existe?", best_weights_path.exists())
print("history.csv existe?", history_path.exists())
print("metrics.json existe?", metrics_path.exists())
print("confusion matrix existe?", cm_path.exists())

if not history_path.exists():
    raise FileNotFoundError(f"history.csv não encontrado: {history_path}")

hist = pd.read_csv(history_path)

best_val_acc_idx = hist["val_acc"].idxmax()
best_val_f1_idx = hist["val_f1"].idxmax()

best_val_acc_row = hist.loc[best_val_acc_idx]
best_val_f1_row = hist.loc[best_val_f1_idx]

summary = {
    "run_dir": str(RUN_DIR),
    "best_weights": str(best_weights_path),
    "best_weights_exists": best_weights_path.exists(),

    "epochs_trained": int(hist["epoch"].max()),

    "best_epoch_by_val_acc": int(best_val_acc_row["epoch"]),
    "best_val_acc": float(best_val_acc_row["val_acc"]),
    "best_val_acc_val_f1": float(best_val_acc_row["val_f1"]),
    "best_val_acc_train_acc": float(best_val_acc_row["train_acc"]),
    "best_val_acc_train_loss": float(best_val_acc_row["train_loss"]),
    "best_val_acc_val_loss": float(best_val_acc_row["val_loss"]),

    "best_epoch_by_val_f1": int(best_val_f1_row["epoch"]),
    "best_val_f1": float(best_val_f1_row["val_f1"]),
    "best_val_f1_val_acc": float(best_val_f1_row["val_acc"]),
}

if metrics_path.exists():
    with open(metrics_path, "r") as f:
        test_metrics = json.load(f)

    summary.update({
        "test_accuracy": test_metrics.get("accuracy"),
        "test_precision_macro": test_metrics.get("precision"),
        "test_recall_macro": test_metrics.get("recall"),
        "test_f1_macro": test_metrics.get("f1"),
        "latency_ms": test_metrics.get("latency_ms"),
        "AP_plastic": test_metrics.get("AP_plastic"),
        "AP_paper": test_metrics.get("AP_paper"),
        "AP_metal": test_metrics.get("AP_metal"),
        "AP_glass": test_metrics.get("AP_glass"),
        "AP_other": test_metrics.get("AP_other"),
    })
else:
    print("\n⚠️ metrics.json não foi encontrado. Talvez o erro no MLflow tenha ocorrido antes de salvar as métricas.")

summary_df = pd.DataFrame([summary]).T.rename(columns={0: "value"})
display(summary_df)

if metrics_path.exists():
    print("\nMétricas de teste:")
    display(pd.DataFrame([test_metrics]))
# Out:
# Run dir: /workspace/runs/path_B_5cls/vit_b16_imagenet
# best.pt existe? True
# history.csv existe? True
# metrics.json existe? True
# confusion matrix existe? True
#                                                                      value
# run_dir                       /workspace/runs/path_B_5cls/vit_b16_imagenet
# best_weights             /workspace/runs/path_B_5cls/vit_b16_imagenet/w...
# best_weights_exists                                                   True
# epochs_trained                                                          28
# best_epoch_by_val_acc                                                   18
# best_val_acc                                                       0.91518
# best_val_acc_val_f1                                                0.90548
# best_val_acc_train_acc                                             0.93241
# best_val_acc_train_loss                                            0.19051
# best_val_acc_val_loss                                              0.34693
# best_epoch_by_val_f1                                                    18
# best_val_f1                                                        0.90548
# best_val_f1_val_acc                                                0.91518
# test_accuracy                                                      0.91537
# test_precision_macro                                               0.88258
# test_recall_macro                                                  0.92785
# test_f1_macro                                                      0.90321
# latency_ms                                                          11.714
# AP_plastic                                                          0.9659
# AP_paper                                                           0.93342
# AP_metal                                                           0.85586
# AP_glass                                                           0.95129
# AP_other                                                           0.96765
# Métricas de teste:
#          classifier  accuracy  precision   recall       f1  latency_ms  \
# 0  vit_b16_imagenet   0.91537    0.88258  0.92785  0.90321      11.714
#
#    AP_plastic  AP_paper  AP_metal  AP_glass  AP_other
# 0      0.9659   0.93342   0.85586   0.95129   0.96765

# %% [markdown]
# ## 9) Avaliação combinada detector + classificador
#
# A avaliação combinada mede o comportamento do sistema completo em modo próximo ao uso real. O script `evaluate_path_B_combined.py` recebe o detector YOLO, a pasta de classificadores do Path B (TTA) e o YAML do dataset para executar a cadeia completa: detectar objetos, recortar regiões, classificar cada crop com o B3 e salvar os resultados finais.
#
# Os parâmetros `det_conf=0.001` e `det_iou=0.6` controlam a etapa de detecção durante a avaliação combinada. O resultado é salvo em `/workspace/results_path_B/b3_5cls_tta`, separando a avaliação final dos artefatos brutos de treino em `/workspace/runs/path_B_5cls`.

# %%
EVAL_PATH_B_COMBINED_SCRIPT = Path("/workspace/TrashScan/eval/evaluate_path_B_combined.py")

DETECTOR_WEIGHTS = Path("/workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt")
CLASSIFIER_DIR = Path("/workspace/runs/path_B_5cls")
DATA_YAML = Path("/workspace/processed_5cls/dataset_path_B.yaml")
OUTPUT_DIR = Path("/workspace/results_path_B/b3_5cls_tta")

cmd = [
    sys.executable, str(EVAL_PATH_B_COMBINED_SCRIPT),
    "--detector_weights", str(DETECTOR_WEIGHTS),
    "--classifier_dir", str(CLASSIFIER_DIR),
    "--classifiers", "vit_b16_imagenet",
    "--data_yaml", str(DATA_YAML),
    "--output", str(OUTPUT_DIR),
    "--device", "0",
    "--imgsz", "640",
    "--det_conf", "0.001",
    "--det_iou", "0.6",
]

print("$", " ".join(shlex.quote(str(x)) for x in cmd))

subprocess.run(
    [str(x) for x in cmd],
    cwd="/workspace",
    check=True,
)
# Out:
# $ /workspace/.venv/bin/python /workspace/TrashScan/eval/evaluate_path_B_combined.py --detector_weights /workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt --classifier_dir /workspace/runs/path_B_5cls --classifiers vit_b16_imagenet --data_yaml /workspace/processed_5cls/dataset_path_B.yaml --output /workspace/results_path_B/b3_5cls_tta --device 0 --imgsz 640 --det_conf 0.001 --det_iou 0.6
# Device: cuda:0
# Test set: /workspace/processed_5cls/test/path_B/images
#
# Loading detector: /workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt
#
# ────────────────────────────────────────────────────────────
#   Evaluating: vit_b16_imagenet
# ────────────────────────────────────────────────────────────
#   Loaded vit_b16_imagenet: 85.8M params from best.pt
#
#   Running combined inference on 1391 test images...
#   vit_b16_imagenet: 100%|██████████| 1391/1391 [02:58<00:00,  7.81it/s]
#   [vit_b16_imagenet]  mAP50=0.6588  mAP50-95=0.4430  fps=7.8
#     AP50 plastic : 0.6710  (n_gt=1313)
#     AP50 paper   : 0.6314  (n_gt=280)
#     AP50 metal   : 0.5902  (n_gt=265)
#     AP50 glass   : 0.7121  (n_gt=88)
#     AP50 other   : 0.6892  (n_gt=1263)
#   Saved: /workspace/results_path_B/b3_5cls_tta/individual/B_vit_b16_imagenet_combined.json
#
# ============================================================
# PATH B COMBINED — FINAL COMPARISON
# ============================================================
# Classifier                  mAP50  mAP50-95    FPS
# ──────────────────────────────────────────────────
#   vit_b16_imagenet         0.6588    0.4430    7.8
# ============================================================
#
# Summary saved: /workspace/results_path_B/b3_5cls_tta/path_B_combined_summary.json
# CompletedProcess(args=['/workspace/.venv/bin/python', '/workspace/TrashScan/eval/evaluate_path_B_combined.py', '--detector_weights', '/workspace/runs/path_A_5cls/yolov11m_o2o/weights/best.pt', '--classifier_dir', '/workspace/runs/path_B_5cls', '--classifiers', 'vit_b16_imagenet', '--data_yaml', '/workspace/processed_5cls/dataset_path_B.yaml', '--output', '/workspace/results_path_B/b3_5cls_tta', '--device', '0', '--imgsz', '640', '--det_conf', '0.001', '--det_iou', '0.6'], returncode=0)
