# %% [markdown]
# # TrashScan — Path A simplificado
#
# Este notebook assume que a estrutura **já está baixada/criada no volume** do RunPod:
#
# - `/workspace/.venv`
# - `/workspace/TrashScan`
# - `/workspace/TACO`
# - `/workspace/external_datasets`
# - `/workspace/processed_4cls`
# - `/workspace/runs`
# - `/workspace/results_path_A`
#
# O foco aqui é rodar o fluxo do **Path A** usando os scripts `.py` do projeto, sem refazer downloads e sem refazer merge/preprocessamento por padrão.
#
# > Observação: os pesos dos modelos **`yolov11m`**, **`yolov8m`** e **`yolov9s`** já foram calculados e devem estar disponíveis em `runs/path_A`.

# %% [markdown]
# ## 0) Antes de abrir/rodar o notebook
#
# No terminal do pod, ative a venv do volume:
#
# ```bash
# cd /workspace
# source .venv/bin/activate
# ```
#
# Se precisar reinstalar dependências:
#
# ```bash
# cd /workspace/TrashScan/env
# python -m pip install -r environment.txt
# ```
#
# No VSCode/Jupyter, selecione o kernel correspondente a:
#
# ```bash
# /workspace/.venv/bin/python
# ```
#
# Para confirmar dentro do notebook, rode a célula abaixo e confira `sys.executable`.

# %% [markdown]
# ## 1) Imports, paths e utilitários

# %%
from pathlib import Path
import os
import sys
import shlex
import subprocess
import shutil

# Caminhos principais no RunPod
WORKSPACE = Path('/workspace')
REPO_ROOT = WORKSPACE / 'TrashScan'

DATA_DIR = REPO_ROOT / 'data'
TRAIN_DIR = REPO_ROOT / 'train' / 'paths'
EVAL_DIR = REPO_ROOT / 'eval'

EXTERNAL_DIR = WORKSPACE / 'external_datasets'
TACO_DIR = WORKSPACE / 'TACO'
PROCESSED_DIR = WORKSPACE / 'processed_5cls'
DATASET_YAML_PATH_A = PROCESSED_DIR / 'dataset_path_A.yaml'

# Treino fica no disco local do pod para evitar I/O lento e cache pesado no volume.
# Se o pod for deletado, salve o essencial de volta no volume antes.
RUNS_PATH_A_DIR = WORKSPACE / 'runs' / 'path_A_5cls'
MLFLOW_DIR = Path('/root/mlflow')

# Resultados finais persistentes no volume
RESULTS_PATH_A_DIR = WORKSPACE / 'results_path_A_5cls'

for p in [RUNS_PATH_A_DIR, MLFLOW_DIR, RESULTS_PATH_A_DIR]:
    p.mkdir(parents=True, exist_ok=True)

print('Python             =', sys.executable)
print('REPO_ROOT          =', REPO_ROOT)
print('TACO_DIR           =', TACO_DIR)
print('EXTERNAL_DIR       =', EXTERNAL_DIR)
print('PROCESSED_DIR      =', PROCESSED_DIR)
print('DATASET_YAML_PATH_A=', DATASET_YAML_PATH_A)
print('RUNS_PATH_A_DIR    =', RUNS_PATH_A_DIR)
print('MLFLOW_DIR         =', MLFLOW_DIR)
print('RESULTS_PATH_A_DIR =', RESULTS_PATH_A_DIR)


def run_cmd(cmd, cwd=WORKSPACE, env=None):
    """Roda comandos de forma previsível no notebook."""
    if isinstance(cmd, str):
        print('$', cmd)
        return subprocess.run(cmd, cwd=str(cwd), shell=True, env=env, check=True)

    print('$', ' '.join(shlex.quote(str(x)) for x in cmd))
    return subprocess.run([str(x) for x in cmd], cwd=str(cwd), env=env, check=True)
# Out:
# Python             = /workspace/.venv/bin/python
# REPO_ROOT          = /workspace/TrashScan
# TACO_DIR           = /workspace/TACO
# EXTERNAL_DIR       = /workspace/external_datasets
# PROCESSED_DIR      = /workspace/processed_5cls
# DATASET_YAML_PATH_A= /workspace/processed_5cls/dataset_path_A.yaml
# RUNS_PATH_A_DIR    = /workspace/runs/path_A_5cls
# MLFLOW_DIR         = /root/mlflow
# RESULTS_PATH_A_DIR = /workspace/results_path_A_5cls

# %% [markdown]
# ## 2) Verificação dos arquivos principais

# %%
required_paths = [
    DATA_DIR / 'merge_datasets.py',
    DATA_DIR / 'preprocess.py',
    TRAIN_DIR / 'train_path_A.py',
    EVAL_DIR / 'evaluate.py',
]

missing = [str(p) for p in required_paths if not p.exists()]

if missing:
    print('Arquivos ausentes:')
    for m in missing:
        print(' -', m)
    raise FileNotFoundError('Há scripts ausentes no clone. Veja a lista acima.')

print('Todos os scripts principais foram encontrados.')
print('Dataset YAML existe?', DATASET_YAML_PATH_A.exists())
# Out:
# Todos os scripts principais foram encontrados.
# Dataset YAML existe? True

# %% [markdown]
# ## 3) Configuração de GPU e treino

# %%
import torch

if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_properties(0).name
    DEVICE = '0'
else:
    gpu_name = 'cpu'
    DEVICE = 'cpu'

# Ajuste se necessário
EPOCHS = 300
BATCH = 16
IMGSZ = 640
PATIENCE = 30

# Pesos já calculados anteriormente: yolov11m, yolov8m, yolov9s.
# Se rodar a célula de treino abaixo, esses modelos serão treinados novamente.
MODELS = [
    'yolov11m'
]

print('Dispositivo:', gpu_name)
print('DEVICE     :', DEVICE)
print('BATCH      :', BATCH)
print('EPOCHS     :', EPOCHS)
print('IMGSZ      :', IMGSZ)
print('PATIENCE   :', PATIENCE)
print('MODELS     :', MODELS)
# Out:
# Dispositivo: NVIDIA RTX A4500
# DEVICE     : 0
# BATCH      : 16
# EPOCHS     : 300
# IMGSZ      : 640
# PATIENCE   : 30
# MODELS     : ['yolov11m']

# %% [markdown]
# ## 4) Merge dos datasets — normalmente NÃO rodar
#
# A estrutura já existe em `/workspace/processed_4cls`, então esta célula fica comentada por padrão.
#
# Rode apenas se você mudar os datasets de origem ou precisar reconstruir `merged_data`.

# %%
merge_script = DATA_DIR / 'merge_datasets.py'

run_cmd([
    sys.executable, str(merge_script),
    '--taco_root', str(TACO_DIR),
    '--external_root', str(EXTERNAL_DIR),
    '--output_root', str(PROCESSED_DIR),
    '--skip_preprocess',
])
# Out:
# $ /workspace/.venv/bin/python /workspace/TrashScan/data/merge_datasets.py --taco_root /workspace/TACO --external_root /workspace/external_datasets --output_root /workspace/processed_5cls --skip_preprocess
#   TACO-dataset-1__annotations.coco:   0%|          | 0/189 [00:00<?, ?it/s]
#   TACO           : 1500 images, 4784 annotations
#   TACO-dataset-1__annotations.coco:   0%|          | 3/1525 [00:00<00:51, 29.61it/s]
#   TACO-dataset-1/_annotations.coco: 189 imgs, 346 anns
#   TACO-dataset-1__annotations.coco:   2%|▏         | 3/189 [00:00<00:06, 28.61it/s]
#   TACO-dataset-1/_annotations.coco: 1525 imgs, 3465 anns
#   TACO-dataset-1/_annotations.coco: 189 imgs, 287 anns
#   TACO-dataset-2__annotations.coco:   0%|          | 0/2001 [00:00<?, ?it/s]
#   TACO-dataset-2/_annotations.coco: 189 imgs, 346 anns
#   TACO-dataset-2__annotations.coco:   0%|          | 0/189 [00:00<?, ?it/s]
#   TACO-dataset-2/_annotations.coco: 2001 imgs, 4740 anns
#   TACO-dataset-3__annotations.coco:   0%|          | 0/461 [00:00<?, ?it/s]
#   TACO-dataset-2/_annotations.coco: 189 imgs, 287 anns
#   TACO-dataset-3__annotations.coco:   0%|          | 0/2950 [00:00<?, ?it/s]
#   TACO-dataset-3/_annotations.coco: 461 imgs, 884 anns
#   TACO-dataset-3__annotations.coco:   1%|          | 3/326 [00:00<00:12, 26.81it/s]
#   TACO-dataset-3/_annotations.coco: 2950 imgs, 6615 anns
#   TACO-dataset-3/_annotations.coco: 326 imgs, 608 anns
#
# Merged → /workspace/processed_5cls/merged_data/annotations.json
#   Total images     : 9519
#   Total annotations: 22362
#   plastic     : 8765
#   paper       : 1860
#   metal       : 1793
#   glass       : 695
#   other       : 9249
#   Copied annotations → /workspace/processed_5cls/merged_data/data/annotations.json
#   Symlinked images → /workspace/processed_5cls/merged_data/data/images
# TACO-compatible structure ready at: /workspace/processed_5cls/merged_data
#
# Run manually:
#   python preprocess.py \
#       --taco_root   /workspace/processed_5cls/merged_data \
#       --output_root /workspace/processed_5cls \
#       --path all
# CompletedProcess(args=['/workspace/.venv/bin/python', '/workspace/TrashScan/data/merge_datasets.py', '--taco_root', '/workspace/TACO', '--external_root', '/workspace/external_datasets', '--output_root', '/workspace/processed_5cls', '--skip_preprocess'], returncode=0)

# %% [markdown]
# ## 5) Pré-processamento Path A — normalmente NÃO rodar
#
# A estrutura `train/val/test` já existe em `/workspace/processed_4cls`, então esta célula fica comentada por padrão.
#
# Rode apenas se você apagou/recriou o dataset processado ou mudou o mapeamento de classes.

# %%
preprocess_script = DATA_DIR / 'preprocess.py'

run_cmd([
    sys.executable, str(preprocess_script),
    '--taco_root', str(PROCESSED_DIR / 'merged_data'),
    '--output_root', str(PROCESSED_DIR),
    '--path', 'A',
])
# Out:
# $ /workspace/.venv/bin/python /workspace/TrashScan/data/preprocess.py --taco_root /workspace/processed_5cls/merged_data --output_root /workspace/processed_5cls --path A
# INFO:albumentations.check_version:A new version of Albumentations is available: 2.0.8 (you have 1.4.10). Upgrade using: pip install --upgrade albumentations
# loading annotations into memory...
# Done (t=0.23s)
# creating index...
# index created!
#   Detected pre-mapped 4-class annotations — skipping TACO remapping
# Class counts before merge: {'glass': 234, 'other': 3438, 'plastic': 4249, 'paper': 671, 'metal': 687}
# Class counts after merge: {'glass': 234, 'other': 3438, 'plastic': 4249, 'paper': 671, 'metal': 687}
# Split → train: 6495  val: 1392  test: 1392
# Class weights: {'plastic': 0.511278, 'metal': 1.125499, 'other': 0.488841, 'glass': 1.77672, 'paper': 1.097661}
#
# [train] Processing 6495 images …
#   Letterbox train: 100%|██████████| 6495/6495 [10:41<00:00, 10.12it/s]
#   Running copy-paste oversampling …
#   Oversampling cap: 4953  (2x median=1310)
#     glass        have=500   generate=4453  final=4953
#     metal        have=1246  generate=3707  final=4953
#     other        have=6605  generate=0     final=6605
#     paper        have=1310  generate=3643  final=4953
#     plastic      have=6038  generate=0     final=6038
#   [plastic] already at/above cap, skipping
#   oversampling [metal]: 100%|██████████| 3707/3707 [03:09<00:00, 19.61it/s]
#   [other] already at/above cap, skipping
#   oversampling [glass]: 100%|██████████| 4453/4453 [02:29<00:00, 29.81it/s]
#   oversampling [paper]: 100%|██████████| 3643/3643 [01:55<00:00, 31.48it/s]
#   [path_A] Generated 11799 synthetic images
#
# [val] Processing 1392 images …
#   Letterbox val: 100%|██████████| 1392/1392 [02:04<00:00, 11.18it/s]
#   Letterbox test:   0%|          | 1/1392 [00:00<03:00,  7.73it/s]
# [test] Processing 1392 images …
#   Letterbox test: 100%|██████████| 1392/1392 [01:58<00:00, 11.78it/s]
# Preprocessing complete.
# Outputs written to: /workspace/processed_5cls
# YOLO dataset config written: /workspace/processed_5cls/dataset_path_A.yaml
# CompletedProcess(args=['/workspace/.venv/bin/python', '/workspace/TrashScan/data/preprocess.py', '--taco_root', '/workspace/processed_5cls/merged_data', '--output_root', '/workspace/processed_5cls', '--path', 'A'], returncode=0)

# %% [markdown]
# ## 6) Conferência do dataset Path A
#
# Confirme que o YAML está apontando para o dataset correto e que usa as 4 classes esperadas.

# %%
import yaml

print('DATASET_YAML_PATH_A =', DATASET_YAML_PATH_A)
print('Existe?', DATASET_YAML_PATH_A.exists())

if DATASET_YAML_PATH_A.exists():
    with open(DATASET_YAML_PATH_A, 'r') as f:
        data_yaml = yaml.safe_load(f)
    print(data_yaml)
# Out:
# DATASET_YAML_PATH_A = /workspace/processed_5cls/dataset_path_A.yaml
# Existe? True
# {'path': '/workspace/processed_5cls', 'train': 'train/path_A/images', 'val': 'val/path_A/images', 'test': 'test/path_A/images', 'nc': 5, 'names': ['plastic', 'paper', 'metal', 'glass', 'other']}

# %% [markdown]
# ## 7) Limpeza opcional de cache `.npy` criado por `cache='disk'`
#
# Se o volume cresceu muito depois de treinar, provavelmente foram criados arquivos `.npy` dentro de `processed_4cls`. Esta célula apenas mostra o tamanho; a deleção fica comentada.
#
# Para evitar recriar isso, no `train_path_A.py` use `cache=False` ou `cache=True`, mas não `cache='disk'`.

# %%
run_cmd('du -sh /workspace/processed_5cls || true')
run_cmd("find /workspace/processed_5cls -type f -name '*.npy' | wc -l")


# run_cmd("find /workspace/processed_5cls -type f -name '*.npy' -delete")
# run_cmd('du -sh /workspace/processed_5cls || true')

# %% [markdown]
# ## 8) Treino Path A
#
# Esta célula roda `train_path_A.py` com saída em `/workspace/runs/path_A`.
#
# Importante: os pesos de **`yolov11m`**, **`yolov8m`** e **`yolov9s`** já foram calculados e estão em `runs`. Rode novamente apenas se quiser retreinar.

# %%
train_script = TRAIN_DIR / 'train_path_A.py'

run_cmd([
    sys.executable, str(train_script),
    '--data', str(DATASET_YAML_PATH_A),
    '--output', str(RUNS_PATH_A_DIR),
    '--models', *MODELS,
    '--epochs', str(EPOCHS),
    '--batch', str(BATCH),
    '--imgsz', str(IMGSZ),
    '--device', str(DEVICE),
    '--patience', str(PATIENCE),
    '--mlflow_uri', str(MLFLOW_DIR),
])
# Out:
# $ /workspace/.venv/bin/python /workspace/TrashScan/train/paths/train_path_A.py --data /workspace/processed_5cls/dataset_path_A.yaml --output /workspace/runs/path_A_5cls --models yolov11m --epochs 300 --batch 16 --imgsz 640 --device 0 --patience 30 --mlflow_uri /root/mlflow
# GPU  : NVIDIA RTX A4500
# VRAM : 21.2 GB
# Loaded class weights: {'plastic': 0.511, 'paper': 1.098, 'metal': 1.125, 'glass': 1.777, 'other': 0.489}
#
# ────────────────────────────────────────────────────────────
#   Model  : yolov11m  (yolo11m.pt)
#   Data   : /workspace/processed_5cls/dataset_path_A.yaml
#   Epochs : 300   Batch : 16   imgsz : 640
# ────────────────────────────────────────────────────────────
# New https://pypi.org/project/ultralytics/8.4.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.2 🚀 Python-3.11.10 torch-2.3.1+cu121 CUDA:0 (NVIDIA RTX A4500, 20171MiB)
# engine/trainer: task=detect, mode=train, model=yolo11m.pt, data=/workspace/processed_5cls/dataset_path_A.yaml, epochs=300, time=None, patience=30, batch=16, imgsz=640, save=True, save_period=-1, cache=True, device=0, workers=8, project=/workspace/runs/path_A_5cls, name=yolov11m, exist_ok=True, pretrained=True, optimizer=AdamW, verbose=True, seed=42, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=True, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=30.0, translate=0.1, scale=0.5, shear=2.0, perspective=0.0, flipud=0.1, fliplr=0.5, bgr=0.0, mosaic=0.5, mixup=0.2, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=/workspace/runs/path_A_5cls/yolov11m
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1414879  ultralytics.nn.modules.head.Detect           [5, [256, 512, 512]]
# YOLO11m summary: 409 layers, 20,056,863 parameters, 20,056,847 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# AMP: checks passed ✅
# train: Scanning /workspace/processed_5cls/train/path_A/labels.cache... 18294 images, 4 backgrounds, 0 corrupt: 100%|██████████| 18294/18294 [00:00<?, ?it/s]
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (20.9GB RAM): 100%|██████████| 18294/18294 [00:45<00:00, 402.85it/s]
# INFO:albumentations.check_version:A new version of Albumentations is available: 2.0.8 (you have 1.4.10). Upgrade using: pip install --upgrade albumentations
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /workspace/processed_5cls/val/path_A/labels.cache... 1392 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1392/1392 [00:00<?, ?it/s]
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (1.6GB RAM): 100%|██████████| 1392/1392 [00:03<00:00, 387.96it/s]
# Plotting labels to /workspace/runs/path_A_5cls/yolov11m/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# 2026/05/02 02:54:40 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2026/05/02 02:54:46 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# MLflow: logging run_id(7020043b377648b39337b3fa51b864af) to runs/mlflow
# MLflow: view at http://127.0.0.1:5000 with 'mlflow server --backend-store-uri runs/mlflow'
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /workspace/runs/path_A_5cls/yolov11m
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/300      9.26G      1.204      2.126      1.539         19        640: 100%|██████████| 1144/1144 [04:48<00:00,  3.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:10<00:00,  4.36it/s]
#                    all       1392       3446      0.204     0.0831     0.0365     0.0128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/300       9.4G      1.172      2.003      1.522         16        640: 100%|██████████| 1144/1144 [04:31<00:00,  4.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.43it/s]
#                    all       1392       3446      0.125      0.208     0.0636     0.0261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/300      9.45G      1.094       1.86       1.46         12        640: 100%|██████████| 1144/1144 [04:26<00:00,  4.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.49it/s]
#                    all       1392       3446      0.154      0.165     0.0908     0.0386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/300      9.45G      1.031      1.728      1.406          6        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.69it/s]
#                    all       1392       3446      0.219      0.167      0.099     0.0408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/300      9.44G     0.9563      1.597      1.357          6        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.71it/s]
#                    all       1392       3446      0.209      0.204      0.134     0.0641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/300      9.45G     0.9108      1.523      1.322         27        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.59it/s]
#                    all       1392       3446      0.197      0.203       0.14     0.0707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/300      9.44G     0.8897       1.47      1.306         12        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.70it/s]
#                    all       1392       3446       0.25      0.255      0.188     0.0941
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/300      9.44G     0.8534        1.4      1.276         12        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.292      0.258      0.211      0.115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/300      9.44G     0.8328      1.369      1.265         19        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.71it/s]
#                    all       1392       3446      0.266      0.272       0.21      0.119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/300      9.54G     0.8297      1.348      1.261         17        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.71it/s]
#                    all       1392       3446      0.263      0.261      0.201      0.108
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/300      9.54G     0.8026      1.293      1.244         10        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.316      0.278      0.233      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/300      9.44G     0.7982      1.282      1.243         16        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.60it/s]
#                    all       1392       3446      0.343      0.312      0.251      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/300      9.45G     0.7901      1.266      1.238          9        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.71it/s]
#                    all       1392       3446      0.345      0.297       0.27      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/300      9.44G      0.774      1.236      1.227         17        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.69it/s]
#                    all       1392       3446      0.407       0.31      0.287       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/300      9.44G     0.7685      1.214       1.22         13        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.61it/s]
#                    all       1392       3446      0.334      0.318      0.282      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/300      9.44G     0.7606      1.199      1.216         26        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.71it/s]
#                    all       1392       3446      0.381      0.331      0.319       0.19
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/300      9.44G     0.7571      1.176       1.21         16        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.56it/s]
#                    all       1392       3446      0.396      0.326       0.31       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/300      9.44G     0.7381      1.162      1.199         10        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.397       0.32       0.31      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/300      9.44G     0.7362      1.147      1.201         10        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.73it/s]
#                    all       1392       3446      0.418      0.367      0.348      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/300      9.44G     0.7188      1.119      1.189         13        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.73it/s]
#                    all       1392       3446      0.396      0.368      0.348      0.214
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/300      9.54G     0.7197      1.112      1.187         16        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.73it/s]
#                    all       1392       3446      0.396      0.339      0.332      0.204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/300      9.45G     0.7127      1.083      1.181         12        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.58it/s]
#                    all       1392       3446      0.442      0.349      0.364       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/300      9.53G     0.7042      1.081      1.176         15        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.75it/s]
#                    all       1392       3446      0.444      0.382      0.375      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/300      9.54G     0.7073      1.064      1.179         12        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.71it/s]
#                    all       1392       3446       0.49       0.36      0.381      0.238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/300      9.53G     0.7079      1.073      1.179         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.72it/s]
#                    all       1392       3446      0.438      0.375      0.369       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/300      9.54G     0.6936      1.043       1.17         17        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.492       0.36      0.392      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/300      9.53G     0.6982      1.045       1.17         12        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.60it/s]
#                    all       1392       3446      0.467      0.386        0.4      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/300      9.53G     0.6854      1.016       1.16         11        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.501       0.38      0.411      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/300      9.54G     0.6895      1.024      1.162         27        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.64it/s]
#                    all       1392       3446      0.489      0.407       0.42      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/300      9.54G     0.6772     0.9965      1.154         16        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446       0.48      0.394      0.414      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/300      9.54G     0.6757      1.005      1.159          9        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.488        0.4      0.422      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/300      9.54G     0.6668     0.9856      1.147         16        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.70it/s]
#                    all       1392       3446      0.507      0.401      0.425      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/300      9.54G     0.6744     0.9926      1.153          8        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.73it/s]
#                    all       1392       3446      0.493      0.414      0.431       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/300      9.54G     0.6639     0.9698      1.146          5        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.59it/s]
#                    all       1392       3446      0.517      0.414      0.448      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/300      9.54G      0.663     0.9713      1.146         12        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.547      0.415       0.45      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/300      9.54G     0.6579     0.9506      1.142         19        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.75it/s]
#                    all       1392       3446      0.528       0.42      0.451      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/300      9.54G     0.6538     0.9459       1.14          7        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.548      0.431      0.459      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/300      9.53G     0.6505     0.9364      1.137          7        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.76it/s]
#                    all       1392       3446      0.575      0.421      0.471      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/300      9.54G     0.6524     0.9391      1.139         20        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.58it/s]
#                    all       1392       3446       0.58      0.421      0.476      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/300      9.54G     0.6403      0.922       1.13         10        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.75it/s]
#                    all       1392       3446      0.567      0.448      0.485      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/300      9.54G     0.6467     0.9231      1.135         13        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.70it/s]
#                    all       1392       3446      0.574      0.445      0.486      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/300      9.54G     0.6417     0.9128      1.131         16        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.574       0.44      0.486      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/300      9.54G     0.6321       0.91      1.122         14        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.574      0.452      0.489       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/300      9.54G     0.6337     0.9028      1.128         17        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.58it/s]
#                    all       1392       3446      0.575      0.456       0.49       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/300      9.54G     0.6321     0.8991      1.126          9        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.75it/s]
#                    all       1392       3446      0.592      0.455      0.494      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/300      9.54G     0.6334     0.8897      1.123         10        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.61it/s]
#                    all       1392       3446      0.596      0.459        0.5      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/300      9.54G     0.6315     0.8943      1.124         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.75it/s]
#                    all       1392       3446      0.602      0.454      0.504       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/300      9.54G     0.6254     0.8784       1.12          6        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.76it/s]
#                    all       1392       3446      0.624      0.447      0.505      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/300      9.54G     0.6201     0.8641      1.115         18        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.72it/s]
#                    all       1392       3446      0.619       0.45      0.505      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/300      9.54G     0.6289     0.8718       1.12          8        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.642       0.45      0.509      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/300      9.54G     0.6164     0.8611      1.114          6        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.59it/s]
#                    all       1392       3446      0.622      0.457       0.51      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/300      9.54G     0.6166     0.8591      1.115         16        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.602      0.466      0.512      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/300      9.54G     0.6188     0.8549      1.116          9        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.609      0.464      0.513       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/300      9.54G     0.6091     0.8386      1.106         16        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.76it/s]
#                    all       1392       3446      0.603       0.47      0.514      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/300      9.54G     0.6181     0.8508      1.115         12        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446        0.6       0.47      0.515      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/300      9.54G     0.6128     0.8503      1.109         12        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.60it/s]
#                    all       1392       3446      0.614      0.459      0.518      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/300      9.54G     0.6135     0.8481      1.111         16        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.615      0.463      0.518      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/300      9.54G     0.6031     0.8301      1.103         20        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.70it/s]
#                    all       1392       3446      0.618      0.468       0.52      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/300      9.54G     0.6104     0.8359      1.106         15        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.76it/s]
#                    all       1392       3446      0.613      0.471      0.522       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/300      9.53G     0.6009     0.8126      1.101         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.75it/s]
#                    all       1392       3446      0.605      0.477      0.525      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/300      9.54G      0.602     0.8224      1.104         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.64it/s]
#                    all       1392       3446      0.603       0.48      0.527      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/300      9.54G      0.604     0.8189      1.106          9        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.612      0.477      0.529      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/300      9.54G     0.6018     0.8123      1.105         11        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.59it/s]
#                    all       1392       3446      0.601      0.483      0.533      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/300      9.54G     0.5947      0.802      1.096          6        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.76it/s]
#                    all       1392       3446      0.603      0.483      0.535      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/300      9.54G     0.5945     0.8017      1.093         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.59it/s]
#                    all       1392       3446      0.608      0.485      0.536      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/300      9.53G     0.5911      0.788      1.095         11        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.76it/s]
#                    all       1392       3446      0.603      0.488      0.538      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/300      9.53G     0.5918     0.7967      1.094          8        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446       0.61      0.487      0.539      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/300      9.53G     0.5942     0.7977      1.096         19        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.76it/s]
#                    all       1392       3446      0.611      0.488      0.541      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/300      9.54G     0.5899     0.7948      1.093         10        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.625      0.489      0.543      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/300      9.54G     0.5921       0.79      1.094          9        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.61it/s]
#                    all       1392       3446      0.623       0.49      0.544      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/300      9.54G     0.5932     0.7827      1.098         15        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.625      0.489      0.545      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/300      9.53G     0.5875     0.7856      1.095         10        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.71it/s]
#                    all       1392       3446      0.627      0.487      0.546      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/300      9.54G     0.5772     0.7633      1.082         10        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.622      0.489      0.548      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/300      9.54G     0.5906     0.7767      1.095         15        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.626      0.488       0.55      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/300      9.53G     0.5808      0.768      1.088         26        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.62it/s]
#                    all       1392       3446      0.622      0.496      0.551       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/300      9.54G     0.5837     0.7722      1.088         18        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.626        0.5      0.552      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/300      9.54G     0.5797     0.7654      1.086          9        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.58it/s]
#                    all       1392       3446      0.619      0.501      0.554      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/300      9.53G     0.5752     0.7537      1.087         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.624      0.501      0.555      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/300      9.53G     0.5734     0.7472      1.083         15        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446       0.64      0.498      0.556      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/300      9.54G     0.5704     0.7497      1.083         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.75it/s]
#                    all       1392       3446      0.644      0.501      0.557      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/300      9.53G     0.5728     0.7502      1.081         23        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.641      0.507      0.559      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/300      9.54G     0.5755     0.7468      1.081         10        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.61it/s]
#                    all       1392       3446      0.642      0.508       0.56      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/300      9.53G     0.5702     0.7332      1.082         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.654      0.504      0.562      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/300      9.54G     0.5676     0.7332      1.076         13        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.75it/s]
#                    all       1392       3446      0.654      0.505      0.563      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/300      9.54G     0.5684     0.7431       1.08         16        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.651      0.509      0.565       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/300      9.54G     0.5665     0.7406      1.078         11        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.651      0.511      0.567      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/300      9.53G     0.5627     0.7301      1.077          8        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.61it/s]
#                    all       1392       3446      0.651      0.514      0.568      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/300      9.53G     0.5657     0.7339      1.081         15        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.653      0.515       0.57      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/300      9.54G     0.5589     0.7117      1.072         11        640: 100%|██████████| 1144/1144 [04:23<00:00,  4.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.58it/s]
#                    all       1392       3446      0.656      0.516      0.571      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/300      9.54G     0.5635      0.724      1.074          7        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446       0.66      0.514      0.573      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/300      9.54G     0.5664     0.7311      1.078         12        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.662      0.514      0.574      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/300      9.54G      0.565     0.7304      1.076         21        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.73it/s]
#                    all       1392       3446       0.66      0.518      0.575      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     116/300      9.53G     0.5322     0.6663      1.054        112        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.61it/s]
#                    all       1392       3446       0.71      0.548       0.61      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     117/300      9.54G     0.5357     0.6632       1.06          9        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.79it/s]
#                    all       1392       3446      0.716      0.547      0.611      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     118/300      9.53G     0.5357     0.6606      1.055         13        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.719      0.546      0.612      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     119/300      9.54G     0.5353     0.6661      1.058         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.72it/s]
#                    all       1392       3446      0.728      0.543      0.614      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     120/300      9.53G      0.546     0.6754       1.06         10        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.727      0.542      0.615      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     121/300      9.54G     0.5335     0.6564      1.054         10        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.63it/s]
#                    all       1392       3446      0.731      0.542      0.616      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     122/300      9.53G     0.5338      0.646      1.054         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.736      0.544      0.617      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     123/300      9.53G     0.5366     0.6526      1.056         12        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.79it/s]
#                    all       1392       3446      0.743      0.543      0.618      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     124/300      9.53G     0.5284     0.6503      1.048         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.67it/s]
#                    all       1392       3446      0.742      0.544      0.618      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     125/300      9.53G     0.5363     0.6491      1.052         16        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446       0.74      0.545      0.621       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     126/300      9.53G     0.5297     0.6463       1.05         13        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.58it/s]
#                    all       1392       3446      0.745      0.545      0.622      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     127/300      9.53G     0.5295     0.6472       1.05         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.76it/s]
#                    all       1392       3446       0.75      0.545      0.623      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     128/300      9.53G     0.5308     0.6514      1.047          7        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.79it/s]
#                    all       1392       3446      0.751      0.546      0.625      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     129/300      9.53G     0.5314       0.65      1.047          7        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.62it/s]
#                    all       1392       3446      0.755      0.548      0.626      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     130/300      9.53G     0.5277     0.6397      1.045         14        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.759      0.553      0.627      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     131/300      9.63G     0.5267     0.6409      1.047          9        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.68it/s]
#                    all       1392       3446      0.758       0.56      0.629      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     132/300      9.44G     0.5293     0.6445      1.051          9        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446       0.76       0.56       0.63      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     133/300      9.44G     0.5279     0.6402      1.046         22        640: 100%|██████████| 1144/1144 [04:26<00:00,  4.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.79it/s]
#                    all       1392       3446      0.761      0.561       0.63      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     134/300      9.44G     0.5228     0.6342      1.045         15        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.61it/s]
#                    all       1392       3446      0.766       0.56      0.631      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     135/300      9.47G     0.5251     0.6326      1.043          8        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.767       0.56      0.632      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     136/300      9.54G     0.5279     0.6398      1.048          6        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.767      0.561      0.633      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     137/300      9.43G     0.5195     0.6249       1.04         11        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.765      0.563      0.634       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     138/300      9.43G     0.5201     0.6193      1.041         18        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.57it/s]
#                    all       1392       3446      0.767      0.565      0.635      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     139/300      9.44G     0.5169     0.6247      1.041         11        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.66it/s]
#                    all       1392       3446      0.767      0.566      0.636      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     140/300      9.53G     0.5167     0.6198       1.04         10        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.766      0.568      0.636      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     141/300      9.53G     0.5167     0.6153       1.04          9        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.766      0.574      0.637      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     142/300      9.53G     0.5205      0.631      1.043         12        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.60it/s]
#                    all       1392       3446      0.767      0.578      0.638      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     143/300      9.43G     0.5174      0.624       1.04          8        640: 100%|██████████| 1144/1144 [04:24<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.767      0.578      0.638      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     144/300      9.44G     0.5138     0.6149       1.04         10        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.769       0.58       0.64      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     145/300      9.53G     0.5154     0.6184       1.04         14        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446      0.764      0.581       0.64      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     146/300      9.44G     0.5159     0.6176       1.04         10        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.771      0.579      0.641      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     147/300      9.46G     0.5176     0.6207      1.042         26        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.61it/s]
#                    all       1392       3446       0.77      0.579      0.642      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     148/300      9.53G     0.5147     0.6096      1.037         11        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.77it/s]
#                    all       1392       3446       0.77       0.58      0.642      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     149/300      9.54G     0.5129     0.6076      1.035         11        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.78it/s]
#                    all       1392       3446      0.771       0.58      0.644      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     150/300      9.44G     0.5096     0.6061      1.033         27        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.61it/s]
#                    all       1392       3446      0.772      0.579      0.644      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     151/300      9.45G     0.5109     0.6087      1.038         12        640: 100%|██████████| 1144/1144 [04:25<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 44/44 [00:09<00:00,  4.74it/s]
#                    all       1392       3446      0.778      0.578      0.644      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     152/300      9.44G     0.5696     0.6141      1.045         39        640:   0%|          | 4/1144 [00:00<04:32,  4.19it/s]

# %% [markdown]
# ## 9) Conferir pesos disponíveis
#
# O avaliador espera encontrar os modelos no formato:
#
# ```text
# /root/runs/path_A/<modelo>/weights/best.pt
# ```

# %%
best_weights = sorted(RUNS_PATH_A_DIR.glob('*/weights/best.pt'))
print(f'Pesos encontrados em {RUNS_PATH_A_DIR}: {len(best_weights)}')
for p in best_weights:
    print(' -', p)

if not best_weights:
    raise FileNotFoundError(f'Nenhum best.pt encontrado em {RUNS_PATH_A_DIR}')

# %% [markdown]
# ## 10) Resumo rápido dos treinos

# %%
run_cmd([
    sys.executable, str(TRAIN_DIR / 'train_path_A.py'),
    '--summarize',
    '--output', str(RUNS_PATH_A_DIR),
])

# %% [markdown]
# ## 11) Avaliação Path A

# %%
evaluate_script = EVAL_DIR / 'evaluate.py'

run_cmd([
    sys.executable, str(evaluate_script),
    '--path', 'A',
    '--runs_dir', str(RUNS_PATH_A_DIR),
    '--data_yaml', str(DATASET_YAML_PATH_A),
    '--output', str(RESULTS_PATH_A_DIR),
    '--device', str(DEVICE),
    '--imgsz', str(IMGSZ),
])

# %% [markdown]
# ## 12) Avaliação TTA + WBF — opcional
#
# A célula abaixo fica comentada porque é mais lenta. Rode apenas se quiser avaliar com test-time augmentation e weighted boxes fusion.

# %%
run_cmd([
    sys.executable, str(EVAL_DIR / 'evaluate.py'),
    '--path', 'A',
    '--runs_dir', str(RUNS_PATH_A_DIR),
    '--data_yaml', str(DATASET_YAML_PATH_A),
    '--output', str(RESULTS_PATH_A_DIR),
    '--device', str(DEVICE),
    '--imgsz', str(IMGSZ),
    "--use_tta_wbf",
    "--tta_scales", "512", "640", "768",
    "--tta_flip",
    "--tta_wbf_iou", "0.55",
    "--tta_skip_box_thr", "0.001",
])

# %% [markdown]
# ## 13) Grid Search TTA + WBF

# %%
import itertools
import subprocess
import sys

# Defina os ranges (ajuste conforme necessário)
tta_wbf_iou_values = [0.45, 0.50, 0.55, 0.60, 0.65]
tta_skip_box_thr_values = [0.0001, 0.001, 0.01, 0.05]

results = []

for iou, skip_thr in itertools.product(tta_wbf_iou_values, tta_skip_box_thr_values):
    print(f"Rodando com IOU={iou}, SKIP_THR={skip_thr}")

    cmd = [
        sys.executable, str(EVAL_DIR / 'evaluate_tta.py'),
        '--path', 'A',
        '--runs_dir', str(RUNS_PATH_A_DIR),
        '--data_yaml', str(DATASET_YAML_PATH_A),
        '--output', str(RESULTS_PATH_A_DIR / f"iou_{iou}_skip_{skip_thr}"),
        '--device', str(DEVICE),
        '--imgsz', str(IMGSZ),
        "--use_tta_wbf",
        "--tta_scales", "512", "640", "768",
        "--tta_flip",
        "--tta_wbf_iou", str(iou),
        "--tta_skip_box_thr", str(skip_thr),
    ]

    subprocess.run(cmd)

    # opcional: guardar configs testadas
    results.append({
        "iou": iou,
        "skip_thr": skip_thr,
        "output_dir": str(RESULTS_PATH_A_DIR / f"iou_{iou}_skip_{skip_thr}")
    })

print("Grid search finalizado!")

# %% [markdown]
# ## 14) Checklist final
#
# Antes de parar/deletar o pod, confirme que o que você quer manter está no volume:
#
# - pesos essenciais em `/workspace/runs/path_A`
# - resultados em `/workspace/results_path_A`
# - projeto em `/workspace/TrashScan`
# - dataset em `/workspace/processed_4cls`

# %%
run_cmd('du -sh /workspace/runs /workspace/results_path_A /workspace/processed_4cls /workspace/TrashScan 2>/dev/null || true')
